# %% [markdown]
# **Exercise 1**: Calculate the multiplication and sum of two numbers
#
# Given two integer numbers, write a Python code to return their product only if the product is equal to or lower than 1000. Otherwise, return their sum.
#
# ![image.png](data:image/png;base64,...)

# %%
number1 = 20
number2 = 30

product = number1*number2

if product <= 1000:
  print("The result is",product)
else:
  print(number1 + number2 )
# Out:
# The result is 600

# %%
number1 = 40
number2 = 30

product = number1*number2

if product <= 1000:
  print("The result is",product)
else:
  print("The result is",number1 + number2 )
# Out:
# The result is 70

# %% [markdown]
# **Exercise 2**: Print the Sum of a Current Number and a Previous number
#
# Write a Python code to iterate the first 10 numbers, and in each iteration, print the sum of the current and previous number.
#
# ![image.png](data:image/png;base64,...)

# %%
previous_number = 0
for i in range(10):
  sum = previous_number+i
  print('Current Number', i ,'Previous Number', previous_number, 'Sum:',sum)
  previous_number = i
# Out:
# Current Number 0 Previous Number 0 Sum: 0
# Current Number 1 Previous Number 0 Sum: 1
# Current Number 2 Previous Number 1 Sum: 3
# Current Number 3 Previous Number 2 Sum: 5
# Current Number 4 Previous Number 3 Sum: 7
# Current Number 5 Previous Number 4 Sum: 9
# Current Number 6 Previous Number 5 Sum: 11
# Current Number 7 Previous Number 6 Sum: 13
# Current Number 8 Previous Number 7 Sum: 15
# Current Number 9 Previous Number 8 Sum: 17

# %% [markdown]
# **Exercise 3**: Print characters present at an even index number
# Write a Python code to accept a string from the user and display characters present at an even index number.
#
# For example, str = "Welcome". so your code should display ‘W’, ‘l’, ‘o’,  ‘e’.
# ![image.png](data:image/png;base64,...)

# %%
string = input('Orignal String is ')
print("Printing only even index chars")


for i in string[0::2]:
  print(i)
# Out:
# Orignal String is Welcome
# Printing only even index chars
# W
# l
# o
# e

# %% [markdown]
# **Exercise 4:** Remove first n characters from a string
# Write a Python code to remove characters from a string from 0 to n and return a new string.
#
# For Example:
#
# remove_chars("Welcome", 4) so output must be tive. Here, you need to remove the first four characters from a string.
#
# remove_chars("Welcome", 2) so output must be native. Here, you need to remove the first two characters from a string.
#
# Note: n must be less than the length of the string.

# %%
string = input("Enter the string ")
print("remove_chars('Welcome', 4) = ",string[4:])
print("remove_chars('Welcome', 2) = ",string[2:])
# Out:
# Enter the string Welcome
# remove_chars('Welcome', 4) =  ome
# remove_chars('Welcome', 2) =  lcome

# %%
def remove_chars(word,n):
  print('Orginal word:', word)
  x = word[n:]
  return x

print('Removing character')
print(remove_chars('Welcome', 4))
print(remove_chars('Welcome', 2))
# Out:
# Removing character
# Orginal word: Welcome
# ome
# Orginal word: Welcome
# lcome

# %% [markdown]
# **Exercise 5**: Check if the first and last numbers of a list are the same
#
# Write a code to return True if the list’s first and last numbers are the same. If the numbers are different, return False.
#
# ![image.png](data:image/png;base64,...)

# %%
number_x = [10,20,30,40,10]
number_y = [75,65,35,75,30]

def first_and_last_number_same(number_list):
  print('Given List:',number_list)
  first_number = number_list[0]
  last_number = number_list[-1]

  if first_number == last_number:
    return True
  else:
    return False

print('result is',first_and_last_number_same(number_x))
print('result is',first_and_last_number_same(number_y))
# Out:
# Given List: [10, 20, 30, 40, 10]
# result is True
# Given List: [75, 65, 35, 75, 30]
# result is False
